# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("/Users/kevin/Desktop/Sang/Sang/Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_id           City Country      Lat      Lng  Max Temp  Humidity  \
# 0        0  Ahmadpur East      PK  29.1431  71.2598     79.74        26
# 1        1      Jamestown      US  42.0970 -79.2353     27.01        55
# 2        2       Temirtau      KZ  50.0544  72.9483     17.26        96
# 3        3   Puerto Ayora      EC  -0.7393 -90.3518     80.55        89
# 4        4  Schwarzenbach      DE  49.7333  12.0000     35.22        41
#
#    Cloudiness  Wind Speed Current Description
# 0           0        5.55           clear sky
# 1         100       10.36     overcast clouds
# 2         100        5.66          light snow
# 3          43        3.00    scattered clouds
# 4           0        4.61           clear sky

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature would you like to travel?"))
max_temp = float(input("What is the maximum temperature would you like to travel?"))
# Out:
# What is the minimum temperature would you like to travel?40
# What is the maximum temperature would you like to travel?80

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
prefer_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)]
prefer_cities_df.head(10)
# Out:
#     City_id            City Country      Lat      Lng  Max Temp  Humidity  \
# 0         0   Ahmadpur East      PK  29.1431  71.2598     79.74        26
# 5         5       Cape Town      ZA -33.9258  18.4232     59.41        63
# 6         6     Debre Tabor      ET  11.8500  38.0167     57.85        64
# 8         8          Castro      BR -24.7911 -50.0119     63.63        98
# 9         9  Saint-Philippe      RE -21.3585  55.7679     76.59        88
# 10       10    San Jeronimo      PE -11.9472 -75.2829     47.98        91
# 12       12    Punta Arenas      CL -53.1500 -70.9167     44.71        65
# 13       13         Margate      GB  51.3813   1.3862     46.31        90
# 14       14      Bredasdorp      ZA -34.5322  20.0403     58.32        63
# 16       16      Oranjemund     NaN -28.5500  16.4333     62.11        75
#
#     Cloudiness  Wind Speed Current Description
# 0            0        5.55           clear sky
# 5           20        8.05          few clouds
# ...

# %%
# 4a. Determine if there are any empty rows.
prefer_cities_df.count()
# Out:
# City_id                413
# City                   413
# Country                406
# Lat                    413
# Lng                    413
# Max Temp               413
# Humidity               413
# Cloudiness             413
# Wind Speed             413
# Current Description    413
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = prefer_cities_df.dropna()
clean_df.count()
# Out:
# City_id                406
# City                   406
# Country                406
# Lat                    406
# Lng                    406
# Max Temp               406
# Humidity               406
# Cloudiness             406
# Wind Speed             406
# Current Description    406
# dtype: int64

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp Current Description      Lat       Lng  \
# 0    Ahmadpur East      PK     79.74           clear sky  29.1431   71.2598
# 5        Cape Town      ZA     59.41          few clouds -33.9258   18.4232
# 6      Debre Tabor      ET     57.85          light rain  11.8500   38.0167
# 8           Castro      BR     63.63     overcast clouds -24.7911  -50.0119
# 9   Saint-Philippe      RE     76.59          light rain -21.3585   55.7679
# 10    San Jeronimo      PE     47.98     overcast clouds -11.9472  -75.2829
# 12    Punta Arenas      CL     44.71    scattered clouds -53.1500  -70.9167
# 13         Margate      GB     46.31     overcast clouds  51.3813    1.3862
# 14      Bredasdorp      ZA     58.32     overcast clouds -34.5322   20.0403
# 18       Busselton      AU     64.51          few clouds -33.6500  115.3333
#
#    Hotel Name
# 0
# 5
# 6
# 8
# 9
# 10
# 12
# 13
# 14
# 18

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try: 
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print ("Hotel not found")
# Out:
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# Hotel not found
# ...

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna()

# %%
# 8a. Create the output File (CSV)
output_file = "WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
